# %% [markdown]
# filters `coteach_visuals_with_categories.csv` dataset to create a test set containing the specific geometric diagram types:
# - 2D shapes: triangle, rectangle, circle
# - 3D shapes: rectangular prism, cube

# %%
import pandas as pd

# %%
INPUT_CSV = "../data/coteach_visuals_with_categories.csv"


OUTPUT_CSV = "../data/geometric_shapes_test_set.csv"

df = pd.read_csv(INPUT_CSV)

print(f"Original dataset shape: {df.shape}")
print(f"Columns: {list(df.columns)}")
df.head()
# Out:
# Original dataset shape: (6000, 5)
# Columns: ['prompt', 'tikz', 'image', 'main_category', 'subcategory']
#                                               prompt  \
# 0  coordinate plane, -5 to 5 on both axes, plot p...
# 1  coordinate plane, -5 to 5 on both axes, plot p...
# 2  histogram, study hours with bars: 0-2 hours (5...
# 3  histogram, study hours with bars: 0-2 hours (5...
# 4  box plot, test scores with min=65, Q1=75, medi...
#
#                                                 tikz  \
# 0  \documentclass{IM}\n\usepackage{tikz}\n\begin{...
# 1  \documentclass{IM}\n\usepackage{tikz}\n\begin{...
# 2  \documentclass{IM}\n\usepackage{tikz}\n\begin{...
# 3  \documentclass{IM}\n\usepackage{tikz}\n\begin{...
# 4  \documentclass{IM}\n\usepackage{tikz}\n\begin{...
#
#                                                image     main_category  \
# 0  https://2xavun1dsa0sayar.public.blob.vercel-st...  coordinate plane
# 1  https://2xavun1dsa0sayar.public.blob.vercel-st...  coordinate plane
# 2  https://2xavun1dsa0sayar.public.blob.vercel-st...        statistics
# 3  https://2xavun1dsa0sayar.public.blob.vercel-st...        statistics
# 4  https://2xavun1dsa0sayar.public.blob.vercel-st...        statistics
#
#   subcategory
# 0         NaN
# 1         NaN
# 2   histogram
# 3   histogram
# 4    box plot

# %%
print(df['main_category'].value_counts())

print("\nSubcategory distribution (top 20):")
print(df['subcategory'].value_counts().head(20))
# Out:
# main_category
# 2d shapes                                                                                                                                                                            1346
# 3d shapes                                                                                                                                                                            1120
# coordinate plane                                                                                                                                                                      574
# statistics                                                                                                                                                                            490
# number line                                                                                                                                                                           296
#                                                                                                                                                                                      ...
# a graph of a proportional relationship with the x-axis labeled 'time (in minutes)' and the y-axis labeled 'distance (in cm)'. the line passes through the origin and the point (1       1
# a graph with an x-axis for 'pounds of apples' and a y-axis for 'total cost ($)'. there are two lines starting from the origin (0                                                        1
# a table with two columns labeled 'questions answered (x)' and 'points earned (y)'. the rows are: (4.0                                                                                   1
# a table with two columns labeled 'hours of homework (x)' and 'hours of gaming (y)'. the rows are: (2                                                                                    1
# a coordinate plane of quadrant i with the x and y axis labeled                                                                                                                          1
# Name: count, Length: 551, dtype: int64
#
# Subcategory distribution (top 20):
# subcategory
# rectangular prism    680
# triangle             471
# rectangle            322
# parallelogram        196
# dot plot             176
# cube                 152
# pyramid              144
# box plot             130
# circle               114
# square               114
# prism                108
# bar chart             92
# histogram             88
# polygon               64
# quadrilateral         28
# 3d solid              20
# trapezoid             14
# star                  13
# cylinder               8
# rhombus                8
# Name: count, dtype: int64

# %%
TARGET_SHAPES = [
    'triangle',
    'rectangle', 
    'circle',
    'rectangular prism',
    'cube'
]

# %%
filtered_df = df[df['subcategory'].isin(TARGET_SHAPES)].copy()

print(f"Filtered dataset shape: {filtered_df.shape}")
# Out:
# Filtered dataset shape: (1739, 5)

# %%
def get_dataset_makeup(df):
    print(f"Dataset shape: {df.shape}")
    
    shape_counts = df['subcategory'].value_counts()
    for shape, count in shape_counts.items():
        print(f"  {shape:18}: {count:3d} rows")
    print(f"Total: {shape_counts.sum()} rows")

    main_cat_counts = df['main_category'].value_counts()
    for cat, count in main_cat_counts.items():
        print(f"  {cat}: {count} rows")

# %%
get_dataset_makeup(filtered_df)
# Out:
# Dataset shape: (1739, 5)
#   rectangular prism : 680 rows
#   triangle          : 471 rows
#   rectangle         : 322 rows
#   cube              : 152 rows
#   circle            : 114 rows
# Total: 1739 rows
#   2d shapes: 907 rows
#   3d shapes: 832 rows

# %%
# Deduplicate
deduplicated_df = filtered_df.drop_duplicates(subset=['prompt', 'tikz'])

get_dataset_makeup(deduplicated_df)
filtered_df = deduplicated_df
# Out:
# Dataset shape: (870, 5)
#   rectangular prism : 340 rows
#   triangle          : 236 rows
#   rectangle         : 161 rows
#   cube              :  76 rows
#   circle            :  57 rows
# Total: 870 rows
#   2d shapes: 454 rows
#   3d shapes: 416 rows

# %%
def sample(df, target_size=400):
      sample_fraction = target_size / len(df)
      sampled_dfs = []

      for shape in TARGET_SHAPES:
          shape_df = df[df['subcategory'] == shape]
          n_sample = int(len(shape_df) * sample_fraction)
          if n_sample > 0:
              sampled_dfs.append(shape_df.sample(n=n_sample,
  random_state=42))

      return pd.concat(sampled_dfs, ignore_index=True)

# %%
# randomly sample 400 via stratified sampling
rater_study_df = sample(filtered_df, target_size=400)

# Show final distribution
print("\nFinal rater study distribution:")
get_dataset_makeup(rater_study_df)
# Out:
# Final rater study distribution:
# Dataset shape: (398, 5)
#   rectangular prism : 156 rows
#   triangle          : 108 rows
#   rectangle         :  74 rows
#   cube              :  34 rows
#   circle            :  26 rows
# Total: 398 rows
#   2d shapes: 208 rows
#   3d shapes: 190 rows

# %%
rater_study_df.to_csv(OUTPUT_CSV, index=False)
print(f"Filtered dataset exported to: {OUTPUT_CSV}")
# Out:
# Filtered dataset exported to: ../data/geometric_shapes_test_set.csv
